# %%
import pandas as pd

# %%
df = pd.read_excel("Spotify_data.xlsx")

# %%
df.head(15)
# Out:
#       Age  Gender spotify_usage_period  \
# 0   20-35  Female    More than 2 years
# 1   12-20    Male    More than 2 years
# 2   35-60  Others   6 months to 1 year
# 3   20-35  Female    1 year to 2 years
# 4   20-35  Female    1 year to 2 years
# 5   20-35    Male    More than 2 years
# 6   20-35  Female    1 year to 2 years
# 7   20-35  Female   Less than 6 months
# 8   20-35  Female   Less than 6 months
# 9   20-35  Female    More than 2 years
# 10  20-35  Female    More than 2 years
# 11  20-35  Female    1 year to 2 years
# 12  20-35  Female    1 year to 2 years
# 13  20-35  Female    More than 2 years
# 14  20-35  Female    More than 2 years
#
#                           spotify_listening_device spotify_subscription_plan  \
# 0               Smart speakers or voice assistants       Free (ad-supported)
# 1                               Computer or laptop       Free (ad-supported)
# 2               Smart speakers or voice assistants       Free (ad-supported)
# ...

# %%
#spotify_listening_device

#music_Influencial_mood

#music_lis_frequency

#music_expl_method

# %%
df['spotify_listening_device'] = df['spotify_listening_device'].str.split(',')
df['music_Influencial_mood'] = df['music_Influencial_mood'].str.split(',')
df['music_lis_frequency'] = df['music_lis_frequency'].str.split(',')
df['music_expl_method'] = df['music_expl_method'].str.split(',')

# %%
df = df.explode('spotify_listening_device')
df = df.explode('music_Influencial_mood')
df = df.explode('music_lis_frequency')
df = df.explode('music_expl_method')

# %%
df.to_csv('spotify_data.csv', index=False)

# %%
df = pd.read_csv("spotify_data.csv")

# %%
import pycaret

# %%
import sklearn

# %%
from pycaret.classification import *
