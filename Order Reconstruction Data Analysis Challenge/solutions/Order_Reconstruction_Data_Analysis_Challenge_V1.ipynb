# %%
# Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal
import scipy.interpolate

# %%
# --- 0. Define Constants ---
# Gear ratio from tachometer to turbine
GEAR_RATIO = 5.095238095
# Nominal bearing fault orders (cycles per revolution)
# [cage, ball, inner race, outer race]
FAULT_ORDERS_BPF = [0.43, 7.05, 10.78, 8.22]
# Vibration signal sample rate
SAMPLE_RATE_HZ = 93750.0

# %%
filenames = ['file_01.csv',
'file_02.csv',
'file_03.csv',
'file_04.csv',
'file_05.csv',
'file_06.csv',
'file_07.csv',
'file_08.csv',
'file_09.csv',
'file_10.csv',
'file_11.csv',
'file_12.csv',
'file_13.csv',
'file_14.csv',
'file_15.csv',
'file_16.csv',
'file_17.csv',
'file_18.csv',
'file_19.csv',
'file_20.csv',
'file_21.csv',
'file_22.csv',
'file_23.csv',
'file_24.csv',
'file_25.csv',
'file_26.csv',
'file_27.csv',
'file_28.csv',
'file_29.csv',
'file_30.csv',
'file_31.csv',
'file_32.csv',
'file_33.csv',
'file_34.csv',
'file_35.csv',
'file_36.csv',
'file_37.csv',
'file_38.csv',
'file_39.csv',
'file_40.csv',
'file_41.csv',
'file_42.csv',
'file_43.csv',
'file_44.csv',
'file_45.csv',
'file_46.csv',
'file_47.csv',
'file_48.csv',
'file_49.csv',
'file_50.csv',
'file_51.csv',
'file_52.csv',
'file_53.csv']

# %%
# Dictionaries to store results
analysis_results = {}
plot_files = []
scoring_results = []

# %%
# --- 1. First Pass: Analyze Speed Stability ---
for filename in filenames:
    print(f"\nAnalyzing {filename}...")

    # Load data
    try:
        df = pd.read_csv(filename)
    except Exception as e:
        print(f"Error loading {filename}: {e}")
        continue

    # Extract vibration signal
    v_signal = df['v'].values

    # Extract sparse tachometer timestamps and drop NaNs
    zct_times = df['zct'].dropna().values

    if len(zct_times) < 2:
        print(f"File {filename} has insufficient tachometer data. Skipping.")
        analysis_results[filename] = {'error': 'Insufficient tach data'}
        continue

    # Calculate time between tach pulses (periods)
    tach_periods = np.diff(zct_times)

    # Calculate instantaneous tachometer frequency (1 / period)
    # We assume 1 pulse per revolution (PPR) for the tachometer
    f_tach_inst = 1.0 / tach_periods

    # Calculate instantaneous turbine frequency
    f_turbine_inst = f_tach_inst * GEAR_RATIO

    # Create a time vector for these frequency values, placing them at the midpoint of each period
    t_freq_axis = zct_times[:-1] + tach_periods / 2.0

    # Calculate speed statistics
    mean_speed_hz = np.mean(f_turbine_inst)
    min_speed_hz = np.min(f_turbine_inst)
    max_speed_hz = np.max(f_turbine_inst)
    speed_variation_percent = 100.0 * (max_speed_hz - min_speed_hz) / mean_speed_hz

    # Store results
    analysis_results[filename] = {
        'mean_turbine_speed_hz': mean_speed_hz,
        'min_turbine_speed_hz': min_speed_hz,
        'max_turbine_speed_hz': max_speed_hz,
        'speed_variation_percent': speed_variation_percent,
        'num_v_samples': len(v_signal),
        'num_tach_pulses': len(zct_times),
        'data_duration_sec': len(v_signal) / SAMPLE_RATE_HZ
    }

    # --- Plot Instantaneous Speed ---
    plt.figure(figsize=(10, 6))
    plt.plot(t_freq_axis, f_turbine_inst)
    plt.title(f'Instantaneous Turbine Speed for {filename}\nMean: {mean_speed_hz:.2f} Hz, Variation: {speed_variation_percent:.2f}%')
    plt.xlabel('Time (s)')
    plt.ylabel('Turbine Speed (Hz)')
    plt.grid(True)
    plt.axhline(mean_speed_hz, color='r', linestyle='--', label=f'Mean ({mean_speed_hz:.2f} Hz)')
    plt.legend()
    plot_filename = f'speed_analysis_{filename}.png'
    plt.savefig(plot_filename)
    plt.close()
    plot_files.append(plot_filename)
# Out:
# Analyzing file_01.csv...
#
# Analyzing file_02.csv...
#
# Analyzing file_03.csv...
#
# Analyzing file_04.csv...
#
# Analyzing file_05.csv...
#
# Analyzing file_06.csv...
#
# Analyzing file_07.csv...
#
# Analyzing file_08.csv...
#
# Analyzing file_09.csv...
#
# Analyzing file_10.csv...
#
# Analyzing file_11.csv...
#
# Analyzing file_12.csv...
#
# Analyzing file_13.csv...
#
# Analyzing file_14.csv...
#
# Analyzing file_15.csv...
#
# Analyzing file_16.csv...
#
# Analyzing file_17.csv...
#
# Analyzing file_18.csv...
#
# Analyzing file_19.csv...
#
# Analyzing file_20.csv...
#
# Analyzing file_21.csv...
#
# Analyzing file_22.csv...
#
# Analyzing file_23.csv...
#
# Analyzing file_24.csv...
#
# Analyzing file_25.csv...
#
# Analyzing file_26.csv...
#
# Analyzing file_27.csv...
#
# Analyzing file_28.csv...
#
# Analyzing file_29.csv...
#
# Analyzing file_30.csv...
#
# Analyzing file_31.csv...
#
# Analyzing file_32.csv...
#
# Analyzing file_33.csv...
#
# Analyzing file_34.csv...
#
# Analyzing file_35.csv...
#
# Analyzing file_36.csv...
#
# Analyzing file_37.csv...
#
# Analyzing file_38.csv...
#
# Analyzing file_39.csv...
#
# Analyzing file_40.csv...
#
# Analyzing file_41.csv...
#
# Analyzing file_42.csv...
#
# Analyzing file_43.csv...
#
# Analyzing file_44.csv...
#
# Analyzing file_45.csv...
#
# Analyzing file_46.csv...
#
# Analyzing file_47.csv...
#
# Analyzing file_48.csv...
#
# Analyzing file_49.csv...
#
# Analyzing file_50.csv...
#
# Analyzing file_51.csv...
#
# Analyzing file_52.csv...
#
# Analyzing file_53.csv...

# %%
# Print summary of speed analysis
print("\n\n--- Speed Variation Analysis Summary ---")
for filename, results in analysis_results.items():
    if 'error' in results:
        print(f"{filename}: {results['error']}")
    else:
        print(f"{filename}:")
        print(f"  - Mean Turbine Speed: {results['mean_turbine_speed_hz']:.2f} Hz (Nominal: 536.27 Hz)")
        print(f"  - Speed Variation: {results['speed_variation_percent']:.2f} %")
        print(f"  - Data Duration: {results['data_duration_sec']:.2f} s")
        print(f"  - Tach Pulses: {results['num_tach_pulses']}")

print(f"\n--- Speed analysis plots generated: {plot_files} ---")
# Out:
# --- Speed Variation Analysis Summary ---
# file_01.csv:
#   - Mean Turbine Speed: 536.02 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.32 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_02.csv:
#   - Mean Turbine Speed: 536.62 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.24 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_03.csv:
#   - Mean Turbine Speed: 536.27 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.50 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_04.csv:
#   - Mean Turbine Speed: 536.21 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.18 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_05.csv:
#   - Mean Turbine Speed: 536.75 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.25 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_06.csv:
#   - Mean Turbine Speed: 535.90 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.20 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_07.csv:
#   - Mean Turbine Speed: 536.55 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.29 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_08.csv:
#   - Mean Turbine Speed: 536.14 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.58 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_09.csv:
#   - Mean Turbine Speed: 536.22 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.46 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_10.csv:
#   - Mean Turbine Speed: 536.00 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.27 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_11.csv:
#   - Mean Turbine Speed: 536.13 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.45 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_12.csv:
#   - Mean Turbine Speed: 536.50 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.12 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_13.csv:
#   - Mean Turbine Speed: 535.97 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.60 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_14.csv:
#   - Mean Turbine Speed: 538.00 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.46 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_15.csv:
#   - Mean Turbine Speed: 536.81 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.21 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_16.csv:
#   - Mean Turbine Speed: 536.66 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.07 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_17.csv:
#   - Mean Turbine Speed: 536.53 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.19 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_18.csv:
#   - Mean Turbine Speed: 536.26 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.23 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_19.csv:
#   - Mean Turbine Speed: 536.51 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.47 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_20.csv:
#   - Mean Turbine Speed: 536.63 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.19 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_21.csv:
#   - Mean Turbine Speed: 536.52 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.39 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_22.csv:
#   - Mean Turbine Speed: 535.79 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.35 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_23.csv:
#   - Mean Turbine Speed: 536.12 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.13 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_24.csv:
#   - Mean Turbine Speed: 536.06 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.12 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_25.csv:
#   - Mean Turbine Speed: 536.72 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.09 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_26.csv:
#   - Mean Turbine Speed: 536.20 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.09 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_27.csv:
#   - Mean Turbine Speed: 536.42 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.18 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_28.csv:
#   - Mean Turbine Speed: 535.94 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.27 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_29.csv:
#   - Mean Turbine Speed: 536.58 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.17 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_30.csv:
#   - Mean Turbine Speed: 536.23 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.25 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_31.csv:
#   - Mean Turbine Speed: 536.04 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.34 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_32.csv:
#   - Mean Turbine Speed: 536.47 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.46 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_33.csv:
#   - Mean Turbine Speed: 536.70 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.40 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_34.csv:
#   - Mean Turbine Speed: 536.27 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.63 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_35.csv:
#   - Mean Turbine Speed: 535.97 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.20 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_36.csv:
#   - Mean Turbine Speed: 536.32 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.44 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_37.csv:
#   - Mean Turbine Speed: 537.34 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.36 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_38.csv:
#   - Mean Turbine Speed: 536.24 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.57 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_39.csv:
#   - Mean Turbine Speed: 536.64 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.14 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_40.csv:
#   - Mean Turbine Speed: 534.98 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.47 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 527
# file_41.csv:
#   - Mean Turbine Speed: 536.11 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.24 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_42.csv:
#   - Mean Turbine Speed: 535.84 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.17 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_43.csv:
#   - Mean Turbine Speed: 536.10 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.25 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_44.csv:
#   - Mean Turbine Speed: 537.27 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.57 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 530
# file_45.csv:
#   - Mean Turbine Speed: 536.17 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.41 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
# file_46.csv:
#   - Mean Turbine Speed: 535.92 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.30 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_47.csv:
#   - Mean Turbine Speed: 535.97 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.28 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_48.csv:
#   - Mean Turbine Speed: 535.70 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.13 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_49.csv:
#   - Mean Turbine Speed: 535.99 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.41 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_50.csv:
#   - Mean Turbine Speed: 535.96 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.21 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_51.csv:
#   - Mean Turbine Speed: 536.11 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.34 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_52.csv:
#   - Mean Turbine Speed: 536.48 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.35 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 529
# file_53.csv:
#   - Mean Turbine Speed: 536.14 Hz (Nominal: 536.27 Hz)
#   - Speed Variation: 0.25 %
#   - Data Duration: 2.00 s
#   - Tach Pulses: 528
#
# --- Speed analysis plots generated: ['speed_analysis_file_01.csv.png', 'speed_analysis_file_02.csv.png', 'speed_analysis_file_03.csv.png', 'speed_analysis_file_04.csv.png', 'speed_analysis_file_05.csv.png', 'speed_analysis_file_06.csv.png', 'speed_analysis_file_07.csv.png', 'speed_analysis_file_08.csv.png', 'speed_analysis_file_09.csv.png', 'speed_analysis_file_10.csv.png', 'speed_analysis_file_11.csv.png', 'speed_analysis_file_12.csv.png', 'speed_analysis_file_13.csv.png', 'speed_analysis_file_14.csv.png', 'speed_analysis_file_15.csv.png', 'speed_analysis_file_16.csv.png', 'speed_analysis_file_17.csv.png', 'speed_analysis_file_18.csv.png', 'speed_analysis_file_19.csv.png', 'speed_analysis_file_20.csv.png', 'speed_analysis_file_21.csv.png', 'speed_analysis_file_22.csv.png', 'speed_analysis_file_23.csv.png', 'speed_analysis_file_24.csv.png', 'speed_analysis_file_25.csv.png', 'speed_analysis_file_26.csv.png', 'speed_analysis_file_27.csv.png', 'speed_analysis_file_28.csv.png', 'speed_analysis_file_29.csv.png', 'speed_analysis_file_30.csv.png', 'speed_analysis_file_31.csv.png', 'speed_analysis_file_32.csv.png', 'speed_analysis_file_33.csv.png', 'speed_analysis_file_34.csv.png', 'speed_analysis_file_35.csv.png', 'speed_analysis_file_36.csv.png', 'speed_analysis_file_37.csv.png', 'speed_analysis_file_38.csv.png', 'speed_analysis_file_39.csv.png', 'speed_analysis_file_40.csv.png', 'speed_analysis_file_41.csv.png', 'speed_analysis_file_42.csv.png', 'speed_analysis_file_43.csv.png', 'speed_analysis_file_44.csv.png', 'speed_analysis_file_45.csv.png', 'speed_analysis_file_46.csv.png', 'speed_analysis_file_47.csv.png', 'speed_analysis_file_48.csv.png', 'speed_analysis_file_49.csv.png', 'speed_analysis_file_50.csv.png', 'speed_analysis_file_51.csv.png', 'speed_analysis_file_52.csv.png', 'speed_analysis_file_53.csv.png'] ---

# %%
# --- 2. Second Pass: Angular Resampling and Envelope Order Analysis ---
print("\n\n--- Proceeding with Angular Resampling and Envelope Order Analysis ---")

for filename in filenames:
    print(f"\nProcessing {filename} for degradation scoring...")

    if 'error' in analysis_results[filename]:
        print(f"Skipping {filename} due to previous error.")
        continue

    # --- 2.1 Load Data ---
    df = pd.read_csv(filename)
    v_signal = df['v'].values
    zct_times = df['zct'].dropna().values

    # Create time vector for vibration signal
    t_v_axis = np.arange(len(v_signal)) / SAMPLE_RATE_HZ

    # --- 2.2 Create Phase-Time Map ---
    # We assume 1 pulse/rev, so each zct_time is a 2*pi radians (360 deg) marker
    # We will create an unwrapped phase vector
    phi_at_zct = np.arange(len(zct_times)) * 2 * np.pi  # Phase in radians

    # Create an interpolator to find the phase at any given time `t`
    # This linearly interpolates the phase between tach pulses
    phase_interpolator = scipy.interpolate.interp1d(
        zct_times,
        phi_at_zct,
        kind='linear',
        fill_value="extrapolate" # Extrapolate to cover edges of the signal
    )

    # Calculate the (unevenly spaced) instantaneous phase for *every* vibration sample
    phi_v_unwrapped = phase_interpolator(t_v_axis)

    # --- 2.3 Perform Angular Resampling ---
    # We now have v(t) and phi(t). We want v(phi).
    # We will create a *new*, *evenly spaced* angular axis
    # The number of samples will be the same, for simplicity
    phi_regular = np.linspace(
        phi_v_unwrapped.min(),
        phi_v_unwrapped.max(),
        len(phi_v_unwrapped)
    )

    # Interpolate the vibration signal `v_signal` from the
    # *uneven* `phi_v_unwrapped` grid onto the *even* `phi_regular` grid
    # This is the core of angular resampling
    v_resampled = np.interp(phi_regular, phi_v_unwrapped, v_signal)

    # --- 2.4 Envelope Analysis in Order Domain ---

    # We must bandpass filter in the angular (order) domain.
    # We need to find a high-frequency resonance band.
    # We'll use the nominal speed to translate the Hz band to an Order band.
    mean_speed_hz = analysis_results[filename]['mean_turbine_speed_hz']

    # Let's target a resonance band of [20 kHz, 40 kHz]
    band_low_hz = 20000.0
    band_high_hz = 40000.0

    # Convert Hz to Order (Order = Freq / Shaft_Speed)
    band_low_order = band_low_hz / mean_speed_hz
    band_high_order = band_high_hz / mean_speed_hz

    # We need the "sampling rate" in the angular domain.
    # This is "samples per revolution".
    total_revolutions = (phi_regular[-1] - phi_regular[0]) / (2 * np.pi)
    num_samples = len(phi_regular)
    samples_per_rev_avg = num_samples / total_revolutions

    # Nyquist order is samples_per_rev_avg / 2
    nyquist_order = samples_per_rev_avg / 2.0

    # Check if our band is valid
    if band_high_order >= nyquist_order:
        print(f"Warning: Desired high band {band_high_order:.1f} exceeds Nyquist order {nyquist_order:.1f}. Clamping.")
        band_high_order = nyquist_order * 0.99

    # Create a 4th-order Butterworth bandpass filter
    try:
        b, a = scipy.signal.butter(
            4,
            [band_low_order, band_high_order],
            btype='band',
            fs=samples_per_rev_avg
        )
    except ValueError as e:
        print(f"Error creating filter for {filename}: {e}. Skipping file.")
        print(f"Filter params: low={band_low_order}, high={band_high_order}, fs={samples_per_rev_avg}")
        scoring_results.append({'file': filename, 'score': 0, 'error': str(e)})
        continue

    # Apply the filter to the angle-resampled signal
    v_resampled_filtered = scipy.signal.lfilter(b, a, v_resampled)

    # --- 2.5 Calculate Envelope & Order Spectrum ---

    # Calculate the analytic signal (Hilbert transform) on the *filtered* signal
    analytic_signal = scipy.signal.hilbert(v_resampled_filtered)

    # Get the envelope (magnitude of the analytic signal)
    envelope = np.abs(analytic_signal)

    # Remove DC component (mean)
    envelope_demeaned = envelope - np.mean(envelope)

    # Calculate the Power Spectrum of the envelope
    # This is the "Envelope Order Spectrum"
    env_spectrum_power = np.abs(np.fft.fft(envelope_demeaned))**2

    # Create the Order axis for the spectrum
    # The 'frequency' in fftfreq is cycles/sample.
    # We want cycles/revolution (Order).
    # Order = (cycles / sample) * (samples / revolution)
    order_axis = np.fft.fftfreq(num_samples) * samples_per_rev_avg

    # Keep only the positive half of the spectrum
    positive_mask = order_axis >= 0
    orders = order_axis[positive_mask]
    spectrum_power = env_spectrum_power[positive_mask]
    spectrum_amplitude = np.sqrt(spectrum_power) # Convert power to amplitude

    # --- 2.6 Score the Spectrum ---
    # We will score based on the peak amplitude at the known fault orders
    score = 0.0
    fault_peak_details = {}

    # We look for the peak in a small band around each fault order
    search_width_order = 0.1 # Look in a band of +/- 0.05 orders

    for fault_name, fault_order in zip(['Cage', 'Ball', 'InnerRace', 'OuterRace'], FAULT_ORDERS_BPF):
        order_min = fault_order - search_width_order / 2.0
        order_max = fault_order + search_width_order / 2.0

        # Find indices within this band
        band_indices = np.where((orders >= order_min) & (orders <= order_max))[0]

        if len(band_indices) > 0:
            # Find the max amplitude in this band
            peak_amplitude_in_band = np.max(spectrum_amplitude[band_indices])

            # Add this peak amplitude to the total score
            # We weight the inner/outer race faults higher as they are more common indicators
            weight = 1.0
            if fault_name == 'InnerRace':
                weight = 2.0
            elif fault_name == 'OuterRace':
                weight = 2.0

            score += peak_amplitude_in_band * weight
            fault_peak_details[fault_name] = peak_amplitude_in_band
        else:
            fault_peak_details[fault_name] = 0.0

    scoring_results.append({
        'file': filename,
        'score': score,
        'peaks': fault_peak_details
    })

    # --- 2.7 Plot the Envelope Order Spectrum ---
    plt.figure(figsize=(12, 7))
    plt.plot(orders, spectrum_amplitude) # Plot amplitude

    # Add vertical lines for fault orders
    colors = ['g', 'b', 'r', 'purple']
    for (fault_name, fault_order), color in zip(zip(['Cage', 'Ball', 'InnerRace', 'OuterRace'], FAULT_ORDERS_BPF), colors):
        plt.axvline(fault_order, color=color, linestyle='--', label=f'{fault_name} ({fault_order})')

    plt.title(f'Envelope Order Spectrum for {filename}\nScore: {score:.2f}')
    plt.xlabel('Order (cycles / turbine revolution)')
    plt.ylabel('Envelope Amplitude')
    plt.legend()
    plt.grid(True)
    plt.xlim(0, 20) # Zoom in on the area of interest

    # Find a reasonable Y-limit
    try:
        # Calculate 99.5th percentile of amplitude in the 0-20 order range
        y_lim_max = np.percentile(spectrum_amplitude[orders <= 20], 99.5)
        plt.ylim(0, y_lim_max * 1.1) # Set Y-limit to 110% of 99.5th percentile
    except:
        pass # Failsafe if percentile calc fails

    spectrum_plot_file = f'envelope_order_spectrum_{filename}.png'
    plt.savefig(spectrum_plot_file)
    plt.close()
    plot_files.append(spectrum_plot_file)
# Out:
# --- Proceeding with Angular Resampling and Envelope Order Analysis ---
#
# Processing file_01.csv for degradation scoring...
#
# Processing file_02.csv for degradation scoring...
#
# Processing file_03.csv for degradation scoring...
#
# Processing file_04.csv for degradation scoring...
#
# Processing file_05.csv for degradation scoring...
#
# Processing file_06.csv for degradation scoring...
#
# Processing file_07.csv for degradation scoring...
#
# Processing file_08.csv for degradation scoring...
#
# Processing file_09.csv for degradation scoring...
#
# Processing file_10.csv for degradation scoring...
#
# Processing file_11.csv for degradation scoring...
#
# Processing file_12.csv for degradation scoring...
#
# Processing file_13.csv for degradation scoring...
#
# Processing file_14.csv for degradation scoring...
#
# Processing file_15.csv for degradation scoring...
#
# Processing file_16.csv for degradation scoring...
#
# Processing file_17.csv for degradation scoring...
#
# Processing file_18.csv for degradation scoring...
#
# Processing file_19.csv for degradation scoring...
#
# Processing file_20.csv for degradation scoring...
#
# Processing file_21.csv for degradation scoring...
#
# Processing file_22.csv for degradation scoring...
#
# Processing file_23.csv for degradation scoring...
#
# Processing file_24.csv for degradation scoring...
#
# Processing file_25.csv for degradation scoring...
#
# Processing file_26.csv for degradation scoring...
#
# Processing file_27.csv for degradation scoring...
#
# Processing file_28.csv for degradation scoring...
#
# Processing file_29.csv for degradation scoring...
#
# Processing file_30.csv for degradation scoring...
#
# Processing file_31.csv for degradation scoring...
#
# Processing file_32.csv for degradation scoring...
#
# Processing file_33.csv for degradation scoring...
#
# Processing file_34.csv for degradation scoring...
#
# Processing file_35.csv for degradation scoring...
#
# Processing file_36.csv for degradation scoring...
#
# Processing file_37.csv for degradation scoring...
#
# Processing file_38.csv for degradation scoring...
#
# Processing file_39.csv for degradation scoring...
#
# Processing file_40.csv for degradation scoring...
#
# Processing file_41.csv for degradation scoring...
#
# Processing file_42.csv for degradation scoring...
#
# Processing file_43.csv for degradation scoring...
#
# Processing file_44.csv for degradation scoring...
#
# Processing file_45.csv for degradation scoring...
#
# Processing file_46.csv for degradation scoring...
#
# Processing file_47.csv for degradation scoring...
#
# Processing file_48.csv for degradation scoring...
#
# Processing file_49.csv for degradation scoring...
#
# Processing file_50.csv for degradation scoring...
#
# Processing file_51.csv for degradation scoring...
#
# Processing file_52.csv for degradation scoring...
#
# Processing file_53.csv for degradation scoring...

# %%
# --- 3. Final Ranking ---
print("\n\n--- Final Degradation Ranking ---")

# Sort by score, ascending (lower score = less degradation)
try:
    ranked_files = sorted(scoring_results, key=lambda x: x.get('score', 0))

    print("Ranked files from LEAST degraded to MOST degraded (Predicted Timeline):")
    for i, result in enumerate(ranked_files):
        print(f"  Rank {i+1}: {result['file']} (Score: {result.get('score', 'N/A'):.2f})")
        if 'peaks' in result:
            print(f"      - InnerRace Peak: {result['peaks'].get('InnerRace', 0):.2f}")
            print(f"      - OuterRace Peak: {result['peaks'].get('OuterRace', 0):.2f}")
            print(f"      - Ball Peak: {result['peaks'].get('Ball', 0):.2f}")
            print(f"      - Cage Peak: {result['peaks'].get('Cage', 0):.2f}")

except Exception as e:
    print(f"Error during final ranking: {e}")
    print("Raw scoring results:")
    for result in scoring_results:
        print(result)

print(f"\nAll generated plots: {plot_files}")
print("Analysis complete.")
# Out:
# --- Final Degradation Ranking ---
# Ranked files from LEAST degraded to MOST degraded (Predicted Timeline):
#   Rank 1: file_06.csv (Score: 119235.33)
#       - InnerRace Peak: 16926.75
#       - OuterRace Peak: 18260.25
#       - Ball Peak: 21262.67
#       - Cage Peak: 27598.67
#   Rank 2: file_36.csv (Score: 122884.92)
#       - InnerRace Peak: 16215.58
#       - OuterRace Peak: 21479.32
#       - Ball Peak: 17997.10
#       - Cage Peak: 29498.03
#   Rank 3: file_16.csv (Score: 123218.38)
#       - InnerRace Peak: 15251.66
#       - OuterRace Peak: 24463.48
#       - Ball Peak: 19582.70
#       - Cage Peak: 24205.38
#   Rank 4: file_15.csv (Score: 124107.84)
#       - InnerRace Peak: 14438.24
#       - OuterRace Peak: 22701.58
#       - Ball Peak: 28759.96
#       - Cage Peak: 21068.23
#   Rank 5: file_26.csv (Score: 126392.04)
#       - InnerRace Peak: 13188.90
#       - OuterRace Peak: 22466.43
#       - Ball Peak: 27512.87
#       - Cage Peak: 27568.51
#   Rank 6: file_46.csv (Score: 126551.59)
#       - InnerRace Peak: 15119.44
#       - OuterRace Peak: 23202.29
#       - Ball Peak: 17030.20
#       - Cage Peak: 32877.94
#   Rank 7: file_37.csv (Score: 129966.11)
#       - InnerRace Peak: 17372.61
#       - OuterRace Peak: 17760.00
#       - Ball Peak: 21861.96
#       - Cage Peak: 37838.93
#   Rank 8: file_11.csv (Score: 132775.49)
#       - InnerRace Peak: 16178.78
#       - OuterRace Peak: 19280.80
#       - Ball Peak: 23604.98
#       - Cage Peak: 38251.35
#   Rank 9: file_28.csv (Score: 134994.28)
#       - InnerRace Peak: 15106.77
#       - OuterRace Peak: 22118.59
#       - Ball Peak: 21820.11
#       - Cage Peak: 38723.44
#   Rank 10: file_48.csv (Score: 136049.11)
#       - InnerRace Peak: 16178.53
#       - OuterRace Peak: 29103.01
#       - Ball Peak: 19943.59
#       - Cage Peak: 25542.45
#   Rank 11: file_32.csv (Score: 137325.16)
#       - InnerRace Peak: 16834.12
#       - OuterRace Peak: 24939.92
#       - Ball Peak: 25275.32
#       - Cage Peak: 28501.76
#   Rank 12: file_22.csv (Score: 138111.11)
#       - InnerRace Peak: 14138.36
#       - OuterRace Peak: 26026.06
#       - Ball Peak: 22871.98
#       - Cage Peak: 34910.31
#   Rank 13: file_47.csv (Score: 140810.79)
#       - InnerRace Peak: 17483.24
#       - OuterRace Peak: 26582.67
#       - Ball Peak: 27302.14
#       - Cage Peak: 25376.82
#   Rank 14: file_38.csv (Score: 142614.91)
#       - InnerRace Peak: 19723.75
#       - OuterRace Peak: 20311.12
#       - Ball Peak: 31205.49
#       - Cage Peak: 31339.68
#   Rank 15: file_12.csv (Score: 144957.61)
#       - InnerRace Peak: 16097.92
#       - OuterRace Peak: 24919.46
#       - Ball Peak: 27252.37
#       - Cage Peak: 35670.48
#   Rank 16: file_39.csv (Score: 146287.14)
#       - InnerRace Peak: 15376.90
#       - OuterRace Peak: 26153.90
#       - Ball Peak: 23145.72
#       - Cage Peak: 40079.82
#   Rank 17: file_34.csv (Score: 146671.94)
#       - InnerRace Peak: 15730.07
#       - OuterRace Peak: 18485.20
#       - Ball Peak: 18804.13
#       - Cage Peak: 59437.26
#   Rank 18: file_21.csv (Score: 148014.81)
#       - InnerRace Peak: 18932.16
#       - OuterRace Peak: 25225.34
#       - Ball Peak: 20143.34
#       - Cage Peak: 39556.48
#   Rank 19: file_17.csv (Score: 152369.85)
#       - InnerRace Peak: 17044.48
#       - OuterRace Peak: 19512.18
#       - Ball Peak: 25651.85
#       - Cage Peak: 53604.68
#   Rank 20: file_31.csv (Score: 154484.19)
#       - InnerRace Peak: 18098.69
#       - OuterRace Peak: 28483.27
#       - Ball Peak: 20287.58
#       - Cage Peak: 41032.70
#   Rank 21: file_14.csv (Score: 155849.60)
#       - InnerRace Peak: 19445.85
#       - OuterRace Peak: 19902.95
#       - Ball Peak: 35182.95
#       - Cage Peak: 41969.05
#   Rank 22: file_40.csv (Score: 159377.82)
#       - InnerRace Peak: 18753.56
#       - OuterRace Peak: 14265.08
#       - Ball Peak: 31145.64
#       - Cage Peak: 62194.92
#   Rank 23: file_09.csv (Score: 162140.80)
#       - InnerRace Peak: 19445.85
#       - OuterRace Peak: 18684.91
#       - Ball Peak: 19137.70
#       - Cage Peak: 66741.57
#   Rank 24: file_10.csv (Score: 162811.35)
#       - InnerRace Peak: 19207.71
#       - OuterRace Peak: 24004.83
#       - Ball Peak: 26613.79
#       - Cage Peak: 49772.49
#   Rank 25: file_53.csv (Score: 168105.81)
#       - InnerRace Peak: 18797.13
#       - OuterRace Peak: 29644.60
#       - Ball Peak: 31318.69
#       - Cage Peak: 39903.66
#   Rank 26: file_45.csv (Score: 171782.42)
#       - InnerRace Peak: 16610.15
#       - OuterRace Peak: 36639.35
#       - Ball Peak: 25623.30
#       - Cage Peak: 39660.11
#   Rank 27: file_01.csv (Score: 174985.91)
#       - InnerRace Peak: 19317.14
#       - OuterRace Peak: 34403.80
#       - Ball Peak: 24070.23
#       - Cage Peak: 43473.80
#   Rank 28: file_50.csv (Score: 175825.32)
#       - InnerRace Peak: 14823.48
#       - OuterRace Peak: 38344.45
#       - Ball Peak: 31502.89
#       - Cage Peak: 37986.57
#   Rank 29: file_33.csv (Score: 176426.11)
#       - InnerRace Peak: 15933.20
#       - OuterRace Peak: 25311.53
#       - Ball Peak: 25989.63
#       - Cage Peak: 67947.02
#   Rank 30: file_44.csv (Score: 177427.32)
#       - InnerRace Peak: 17377.42
#       - OuterRace Peak: 29626.23
#       - Ball Peak: 40837.74
#       - Cage Peak: 42582.28
#   Rank 31: file_27.csv (Score: 182017.86)
#       - InnerRace Peak: 23490.64
#       - OuterRace Peak: 26295.19
#       - Ball Peak: 35066.92
#       - Cage Peak: 47379.28
#   Rank 32: file_05.csv (Score: 186571.71)
#       - InnerRace Peak: 22305.65
#       - OuterRace Peak: 27608.68
#       - Ball Peak: 46133.32
#       - Cage Peak: 40609.74
#   Rank 33: file_24.csv (Score: 190478.46)
#       - InnerRace Peak: 19100.02
#       - OuterRace Peak: 33723.54
#       - Ball Peak: 41651.89
#       - Cage Peak: 43179.45
#   Rank 34: file_20.csv (Score: 191035.08)
#       - InnerRace Peak: 16974.15
#       - OuterRace Peak: 47854.29
#       - Ball Peak: 20735.93
#       - Cage Peak: 40642.27
#   Rank 35: file_42.csv (Score: 191169.16)
#       - InnerRace Peak: 38476.65
#       - OuterRace Peak: 29677.37
#       - Ball Peak: 23524.66
#       - Cage Peak: 31336.47
#   Rank 36: file_03.csv (Score: 191618.43)
#       - InnerRace Peak: 17764.19
#       - OuterRace Peak: 17238.78
#       - Ball Peak: 48189.63
#       - Cage Peak: 73422.86
#   Rank 37: file_19.csv (Score: 193038.28)
#       - InnerRace Peak: 16350.86
#       - OuterRace Peak: 41812.43
#       - Ball Peak: 38578.20
#       - Cage Peak: 38133.51
#   Rank 38: file_51.csv (Score: 195490.00)
#       - InnerRace Peak: 22665.06
#       - OuterRace Peak: 33902.84
#       - Ball Peak: 25945.84
#       - Cage Peak: 56408.36
#   Rank 39: file_18.csv (Score: 204264.80)
#       - InnerRace Peak: 17330.88
#       - OuterRace Peak: 29984.42
#       - Ball Peak: 56464.57
#       - Cage Peak: 53169.63
#   Rank 40: file_30.csv (Score: 205221.47)
#       - InnerRace Peak: 17400.55
#       - OuterRace Peak: 32043.36
#       - Ball Peak: 41147.50
#       - Cage Peak: 65186.15
#   Rank 41: file_52.csv (Score: 207776.21)
#       - InnerRace Peak: 17633.05
#       - OuterRace Peak: 28612.29
#       - Ball Peak: 52212.54
#       - Cage Peak: 63072.98
#   Rank 42: file_35.csv (Score: 212129.38)
#       - InnerRace Peak: 24885.74
#       - OuterRace Peak: 33235.19
#       - Ball Peak: 42787.81
#       - Cage Peak: 53099.71
#   Rank 43: file_08.csv (Score: 213160.12)
#       - InnerRace Peak: 57444.64
#       - OuterRace Peak: 24470.46
#       - Ball Peak: 18493.78
#       - Cage Peak: 30836.14
#   Rank 44: file_29.csv (Score: 219923.76)
#       - InnerRace Peak: 22168.33
#       - OuterRace Peak: 27288.19
#       - Ball Peak: 29757.68
#       - Cage Peak: 91253.05
#   Rank 45: file_23.csv (Score: 228716.25)
#       - InnerRace Peak: 20103.49
#       - OuterRace Peak: 24714.20
#       - Ball Peak: 75142.10
#       - Cage Peak: 63938.76
#   Rank 46: file_25.csv (Score: 228755.15)
#       - InnerRace Peak: 22345.23
#       - OuterRace Peak: 32257.02
#       - Ball Peak: 71993.79
#       - Cage Peak: 47556.85
#   Rank 47: file_49.csv (Score: 237767.95)
#       - InnerRace Peak: 16074.98
#       - OuterRace Peak: 43837.40
#       - Ball Peak: 77996.97
#       - Cage Peak: 39946.22
#   Rank 48: file_41.csv (Score: 239864.91)
#       - InnerRace Peak: 16780.84
#       - OuterRace Peak: 27930.28
#       - Ball Peak: 90439.48
#       - Cage Peak: 60003.19
#   Rank 49: file_07.csv (Score: 241492.53)
#       - InnerRace Peak: 13997.59
#       - OuterRace Peak: 56833.95
#       - Ball Peak: 50944.70
#       - Cage Peak: 48884.76
#   Rank 50: file_43.csv (Score: 250076.24)
#       - InnerRace Peak: 16930.66
#       - OuterRace Peak: 30881.18
#       - Ball Peak: 104511.56
#       - Cage Peak: 49941.01
#   Rank 51: file_13.csv (Score: 256497.09)
#       - InnerRace Peak: 13174.40
#       - OuterRace Peak: 22615.04
#       - Ball Peak: 141773.33
#       - Cage Peak: 43144.88
#   Rank 52: file_02.csv (Score: 258588.59)
#       - InnerRace Peak: 12130.63
#       - OuterRace Peak: 47640.94
#       - Ball Peak: 101290.43
#       - Cage Peak: 37755.01
#   Rank 53: file_04.csv (Score: 271657.33)
#       - InnerRace Peak: 21395.19
#       - OuterRace Peak: 59929.23
#       - Ball Peak: 45901.82
#       - Cage Peak: 63106.69
#
# All generated plots: ['speed_analysis_file_01.csv.png', 'speed_analysis_file_02.csv.png', 'speed_analysis_file_03.csv.png', 'speed_analysis_file_04.csv.png', 'speed_analysis_file_05.csv.png', 'speed_analysis_file_06.csv.png', 'speed_analysis_file_07.csv.png', 'speed_analysis_file_08.csv.png', 'speed_analysis_file_09.csv.png', 'speed_analysis_file_10.csv.png', 'speed_analysis_file_11.csv.png', 'speed_analysis_file_12.csv.png', 'speed_analysis_file_13.csv.png', 'speed_analysis_file_14.csv.png', 'speed_analysis_file_15.csv.png', 'speed_analysis_file_16.csv.png', 'speed_analysis_file_17.csv.png', 'speed_analysis_file_18.csv.png', 'speed_analysis_file_19.csv.png', 'speed_analysis_file_20.csv.png', 'speed_analysis_file_21.csv.png', 'speed_analysis_file_22.csv.png', 'speed_analysis_file_23.csv.png', 'speed_analysis_file_24.csv.png', 'speed_analysis_file_25.csv.png', 'speed_analysis_file_26.csv.png', 'speed_analysis_file_27.csv.png', 'speed_analysis_file_28.csv.png', 'speed_analysis_file_29.csv.png', 'speed_analysis_file_30.csv.png', 'speed_analysis_file_31.csv.png', 'speed_analysis_file_32.csv.png', 'speed_analysis_file_33.csv.png', 'speed_analysis_file_34.csv.png', 'speed_analysis_file_35.csv.png', 'speed_analysis_file_36.csv.png', 'speed_analysis_file_37.csv.png', 'speed_analysis_file_38.csv.png', 'speed_analysis_file_39.csv.png', 'speed_analysis_file_40.csv.png', 'speed_analysis_file_41.csv.png', 'speed_analysis_file_42.csv.png', 'speed_analysis_file_43.csv.png', 'speed_analysis_file_44.csv.png', 'speed_analysis_file_45.csv.png', 'speed_analysis_file_46.csv.png', 'speed_analysis_file_47.csv.png', 'speed_analysis_file_48.csv.png', 'speed_analysis_file_49.csv.png', 'speed_analysis_file_50.csv.png', 'speed_analysis_file_51.csv.png', 'speed_analysis_file_52.csv.png', 'speed_analysis_file_53.csv.png', 'envelope_order_spectrum_file_01.csv.png', 'envelope_order_spectrum_file_02.csv.png', 'envelope_order_spectrum_file_03.csv.png', 'envelope_order_spectrum_file_04.csv.png', 'envelope_order_spectrum_file_05.csv.png', 'envelope_order_spectrum_file_06.csv.png', 'envelope_order_spectrum_file_07.csv.png', 'envelope_order_spectrum_file_08.csv.png', 'envelope_order_spectrum_file_09.csv.png', 'envelope_order_spectrum_file_10.csv.png', 'envelope_order_spectrum_file_11.csv.png', 'envelope_order_spectrum_file_12.csv.png', 'envelope_order_spectrum_file_13.csv.png', 'envelope_order_spectrum_file_14.csv.png', 'envelope_order_spectrum_file_15.csv.png', 'envelope_order_spectrum_file_16.csv.png', 'envelope_order_spectrum_file_17.csv.png', 'envelope_order_spectrum_file_18.csv.png', 'envelope_order_spectrum_file_19.csv.png', 'envelope_order_spectrum_file_20.csv.png', 'envelope_order_spectrum_file_21.csv.png', 'envelope_order_spectrum_file_22.csv.png', 'envelope_order_spectrum_file_23.csv.png', 'envelope_order_spectrum_file_24.csv.png', 'envelope_order_spectrum_file_25.csv.png', 'envelope_order_spectrum_file_26.csv.png', 'envelope_order_spectrum_file_27.csv.png', 'envelope_order_spectrum_file_28.csv.png', 'envelope_order_spectrum_file_29.csv.png', 'envelope_order_spectrum_file_30.csv.png', 'envelope_order_spectrum_file_31.csv.png', 'envelope_order_spectrum_file_32.csv.png', 'envelope_order_spectrum_file_33.csv.png', 'envelope_order_spectrum_file_34.csv.png', 'envelope_order_spectrum_file_35.csv.png', 'envelope_order_spectrum_file_36.csv.png', 'envelope_order_spectrum_file_37.csv.png', 'envelope_order_spectrum_file_38.csv.png', 'envelope_order_spectrum_file_39.csv.png', 'envelope_order_spectrum_file_40.csv.png', 'envelope_order_spectrum_file_41.csv.png', 'envelope_order_spectrum_file_42.csv.png', 'envelope_order_spectrum_file_43.csv.png', 'envelope_order_spectrum_file_44.csv.png', 'envelope_order_spectrum_file_45.csv.png', 'envelope_order_spectrum_file_46.csv.png', 'envelope_order_spectrum_file_47.csv.png', 'envelope_order_spectrum_file_48.csv.png', 'envelope_order_spectrum_file_49.csv.png', 'envelope_order_spectrum_file_50.csv.png', 'envelope_order_spectrum_f ...
# Analysis complete.
