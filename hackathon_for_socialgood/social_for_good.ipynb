# %%
import pandas as pd
import numpy as np

# %%
df_2000_2015 = pd.read_excel("otf_2000_2015.xlsx")

# %%
df_2015_2019 = pd.read_excel("otf_2015_2019.xlsx")

# %%
df_2000_2015.head()
# Out:
#   Funding Org:Org subventionnaire Country Served:Pays servis  \
# 0     Ontario Trillium Foundation                     Canada
# 1     Ontario Trillium Foundation                     Canada
# 2     Ontario Trillium Foundation                     Canada
# 3     Ontario Trillium Foundation                     Canada
# 4     Ontario Trillium Foundation                     Canada
#
#   Province Served:Province servis Fiscal Year:AnnÈe fiscal  \
# 0                         Ontario                2014-2015
# 1                         Ontario                2014-2015
# 2                         Ontario                2014-2015
# 3                         Ontario                2014-2015
# 4                         Ontario                2014-2015
#
#   Grant Programme:Title:Programme, titre  \
# 0                  Community Investments
# 1                  Community Investments
# 2                  Community Investments
# 3                  Community Investments
# ...

# %%
df_2000_2015.shape
# Out:
# (22686, 26)

# %%
df_2015_2019.head()
# Out:
#   Funding Org:Org subventionnaire Country Served:Pays servis  \
# 0     Ontario Trillium Foundation                     Canada
# 1     Ontario Trillium Foundation                     Canada
# 2     Ontario Trillium Foundation                     Canada
# 3     Ontario Trillium Foundation                     Canada
# 4     Ontario Trillium Foundation                     Canada
#
#   Province Served:Province servis Fiscal Year:Année fiscal  \
# 0                         Ontario                2019-2020
# 1                         Ontario                2019-2020
# 2                         Ontario                2019-2020
# 3                         Ontario                2019-2020
# 4                         Ontario                2019-2020
#
#   Grant Programme:Title:Programme, titre  \
# 0                  Community Investments
# 1                  Community Investments
# 2                  Community Investments
# 3                  Community Investments
# ...

# %%
df_2015_2019.shape
# Out:
# (2934, 32)

# %%
df_2015_2019.columns.values.tolist()
# Out:
# ['Funding Org:Org subventionnaire',
#  'Country Served:Pays servis',
#  'Province Served:Province servis',
#  'Fiscal Year:Année fiscal',
#  'Grant Programme:Title:Programme, titre',
#  'Geographical Area Served:Région servis',
#  'Cross-catchment indicator:Indicateur interrégional',
#  'Identifier:Identificateur',
#  "Organization name:Nom d'organisme",
#  'Submission date:Date de soumission',
#  'Approval date:Date approvée',
#  'Amount Applied For:Montant demandé',
#  'Amount Awarded:Montant décerné',
#  'Planned Dates:Duration (months):Dates planifiées:durée(mois)',
#  'Description (English/Anglais)',
#  'Description (French/Français)',
#  'Program Area:Région de programme',
#  'Budget Fund:Fonds du budget',
#  "Recipient Org:Incorporation Number:Org du bénéficiaires: Numéro d'incorporation",
#  "Recipient Org:Charitable Registration Number: Org du bénéficiaires:Numéro d'enregistrement d'organisme de bienfaisance",
#  'Recipient Org:City:Org du bénéficiaires:Ville',
# ...

# %%
df_2000_2015.columns.values.tolist()
# Out:
# ['Funding Org:Org subventionnaire',
#  'Country Served:Pays servis',
#  'Province Served:Province servis',
#  'Fiscal Year:AnnÈe fiscal',
#  'Grant Programme:Title:Programme, titre',
#  'Geographical Area Served:RÈgion servis',
#  'Cross-catchment indicator:',
#  'Identifier:Identificateur',
#  "Organization name:Nom d'organisme",
#  'Submission date:Date de soumission',
#  'Approval date:Date approvÈe',
#  'Amount Applied For:Montant demandÈ',
#  'Amount Awarded:Montant dÈcernÈ',
#  'Planned Dates:Duration (months):Dates planifiÈes:durÈe(mois)',
#  'Description (English/Anglais)',
#  'Description (French/FranÁais)',
#  'Program Area:RÈgion de programme',
#  'Budget Fund:Fonds du budget',
#  "Recipient Org:Incorporation Number:Org du bÈnÈficiaires: NumÈro d'incorporation",
#  "Recipient Org:Charitable Registration Number: Org du bÈnÈficiaires:NumÈro d'enregistrement d'organisme de bienfaisance",
#  'Recipient Org:City:Org du bÈnÈficiaires:Ville',
# ...

# %%
#rename columns
df_2000_2015.columns = ["funding_org","Country_serve","Province_served","fiscal_year","grant_program","geographical_area_served",
                    "cross_catchment_indicator","identifier","organization_name",'submission_date','approval_date',
                    'amount_applied_for',"amount_awarded","planned_dates",'english_description',"french_description",
                    'program_area','budget_fund','recipient_org_incorporation_number',
                        'recipient_org_charitable_registration_number',
                     'recipient_org_city','recipient_org_postal_code','co_application',
                        'population_served','age_group','last_modified']

# %%
df_2015_2019.columns = ["funding_org","Country_serve","Province_served","fiscal_year","grant_program","geographical_area_served",
                    "cross_catchment_indicator","identifier","organization_name",'submission_date','approval_date',
                    'amount_applied_for',"amount_awarded","planned_dates",'english_description',"french_description",
                    'program_area','budget_fund','recipient_org_incorporation_number',
                        'recipient_org_charitable_registration_number',
                     'recipient_org_city','recipient_org_postal_code','co_application',
                        'population_served','age_group','grant_result','rescinded_recovered','rescinded_initiated',
                        'amount_rescinded','last_modified','unamed1','unamed2']

# %%
#select key columns for 2015 to 2019
df_2015_2019 = df_2015_2019[["funding_org","Country_serve","Province_served","fiscal_year","grant_program","geographical_area_served",
                    "cross_catchment_indicator","identifier","organization_name",'submission_date','approval_date',
                    'amount_applied_for',"amount_awarded","planned_dates",'english_description',"french_description",
                    'program_area','budget_fund','recipient_org_incorporation_number',
                        'recipient_org_charitable_registration_number',
                     'recipient_org_city','recipient_org_postal_code','co_application',
                        'population_served','age_group','last_modified']]

# %%
#combine data
df_final =df_2000_2015.append(df_2015_2019, sort=False)

# %%
df_final.head()
# Out:
#                    funding_org Country_serve Province_served fiscal_year  \
# 0  Ontario Trillium Foundation        Canada         Ontario   2014-2015
# 1  Ontario Trillium Foundation        Canada         Ontario   2014-2015
# 2  Ontario Trillium Foundation        Canada         Ontario   2014-2015
# 3  Ontario Trillium Foundation        Canada         Ontario   2014-2015
# 4  Ontario Trillium Foundation        Canada         Ontario   2014-2015
#
#            grant_program                   geographical_area_served  \
# 0  Community Investments                                    Toronto
# 1  Community Investments  Durham, Haliburton, Kawartha & Pine Ridge
# 2  Community Investments                 Grey, Bruce, Huron & Perth
# 3  Community Investments                                Halton Peel
# 4  Community Investments                                    Niagara
#
#   cross_catchment_indicator      identifier  \
# 0                        No  '4868630001300
# ...

# %%
df_final.shape
# Out:
# (25620, 26)

# %%
#summary statistics
df_final.describe()
# Out:
#        amount_applied_for  amount_awarded  planned_dates
# count        2.562000e+04    2.562000e+04   25620.000000
# mean         1.048773e+05    8.182834e+04      17.555211
# std          1.232786e+05    9.997818e+04      11.364574
# min          5.000000e+02    5.000000e+02       1.000000
# 25%          2.500000e+04    2.300000e+04      12.000000
# 50%          6.960000e+04    5.000000e+04      12.000000
# 75%          1.446000e+05    1.000000e+05      24.000000
# max          2.400000e+06    2.400000e+06      60.000000

# %%
#Simple data summary
pd.pivot_table(df_final,index=["organization_name"])
# Out:
#                                                     amount_applied_for  \
# organization_name
# #11 Royal Canadian Army Cadet Corps                            22400.0
# #41 Port Perry Royal Canadian Army Cadet Corps ...             75000.0
# #638 Algonquin Squadron                                        36500.0
# '9 to 5' for Twenty-One Plus, Family Network c/...             22500.0
# 'Building Leaders, Increasing Health' - Waterlo...            211160.0
# ...                                                                ...
# …coles en santÈ rÈgion de Toronto a/s Centre fr...             84992.0
# …ditions Prise de parole inc.                                 227900.0
# …quipe Psycho-sociale                                         173500.0
# …quipe d'hygiËne mentale pour les enfants, adol...             79562.0
# …quipe de dÈveloppement Èconomique rÈgional d'O...             23415.0
#
#                                                     amount_awarded  \
# organization_name
# ...

# %% [markdown]
# ## Data Visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#visualization
#vs amount given

#recipeint org city 
#budget fund
#grant program
#organization name 
#year 
#age group

# %%
#amount given vs recipeient org city
